# %%
import pandas as pd
import os

# %%
# python3 -m cProfile -s tottime inverse_qsar_cli.py args.json generated_drugs/custom_lipi_8.csv > cprofile_log.txt

# %%
with open('cprofile_log.txt', 'r') as f:
    contents = f.read()

# %%
contents
# Out:
# "Compiling models...\nStarting GA...\n\x1bWrote molecules to file\x1b\n         11507306 function calls (11123479 primitive calls) in 79.459 seconds\n\n   Ordered by: standard name\n\n   ncalls  tottime  percall  cumtime  percall filename:lineno(function)\n        1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amax)\n     1080    0.003    0.000    0.039    0.000 <__array_function__ internals>:177(array_equal)\n      837    0.001    0.000    0.007    0.000 <__array_function__ internals>:177(atleast_1d)\n      840    0.002    0.000    0.009    0.000 <__array_function__ internals>:177(concatenate)\n       11    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copyto)\n      837    0.002    0.000    0.025    0.000 <__array_function__ internals>:177(hstack)\n        3    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(mean)\n      186    0.001    0.000    0.002    0.000 <__array_function__ internals>:177(ndim)\n        1    
# ...
